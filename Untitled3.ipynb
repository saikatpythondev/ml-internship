# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
file=pd.read_csv(r"F:\download from c to e\archive (2)\Mall_Customers.csv")

# %%
file
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
file.drop("CustomerID",axis=1,inplace=True)

# %%
file.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
sns.countplot(file["Gender"])
# Out:
# E:\anaconda_30_5_22\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.pie(file.Gender.value_counts(),labels=["male","female"],autopct="%1.1f%%")
plt.show()

# %%
sns.histplot(file["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
file.replace({"Male":1,"Female":0},inplace=True)

# %%
file.isna().sum()
# Out:
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
print(file.corr())
sns.heatmap(file.corr())
# Out:
#                           Gender       Age  Annual Income (k$)  \
# Gender                  1.000000  0.060867            0.056410
# Age                     0.060867  1.000000           -0.012398
# Annual Income (k$)      0.056410 -0.012398            1.000000
# Spending Score (1-100) -0.058109 -0.327227            0.009903
#
#                         Spending Score (1-100)
# Gender                               -0.058109
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000
# <AxesSubplot:>

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=3)
km.fit(file)
# Out:
# KMeans(n_clusters=3)

# %%
err=[]
num=[]
for i in range(1,10):
    km=KMeans(n_clusters=i)
    km.fit(file)
    err.append(km.inertia_)
    num.append(i)
# Out:
# E:\anaconda_30_5_22\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(num,err)

# %%
km=KMeans(n_clusters=6)
km.fit(file)
# Out:
# KMeans(n_clusters=6)

# %%
pred=km.predict(file)

# %%
file["predict"]=pred

# %%
file
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  predict
# 0         1   19                  15                      39        5
# 1         1   21                  15                      81        2
# 2         0   20                  16                       6        5
# 3         0   23                  16                      77        2
# 4         0   31                  17                      40        5
# ..      ...  ...                 ...                     ...      ...
# 195       0   35                 120                      79        0
# 196       0   45                 126                      28        4
# 197       1   32                 126                      74        0
# 198       1   32                 137                      18        4
# 199       1   30                 137                      83        0
#
# [200 rows x 5 columns]

# %%
sns.scatterplot(x=file["Age"],y=file["Spending Score (1-100)"],hue=file["predict"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Spending Score (1-100)'>

# %%
sns.scatterplot(x=file["Annual Income (k$)"],y=file["Spending Score (1-100)"],hue=file["predict"])
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
from sklearn.model_selection import train_test_split

# %%
dependent=file.drop("predict",axis=1)
independent=file["predict"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(dependent,independent,test_size=0.2,random_state=True)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pre=dt.predict(xtest)

# %%
dt.score(xtest,ytest)
# Out:
# 0.925

# %%
from sklearn import tree

# %%
text_representation = tree.export_text(dt)
print(text_representation)
# Out:
# |--- feature_3 <= 62.00
# |   |--- feature_3 <= 39.50
# |   |   |--- feature_2 <= 54.50
# |   |   |   |--- class: 5
# |   |   |--- feature_2 >  54.50
# |   |   |   |--- feature_2 <= 70.50
# |   |   |   |   |--- class: 3
# |   |   |   |--- feature_2 >  70.50
# |   |   |   |   |--- feature_3 <= 33.00
# |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- feature_3 >  33.00
# |   |   |   |   |   |--- feature_3 <= 34.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_3 >  34.50
# |   |   |   |   |   |   |--- class: 4
# |   |--- feature_3 >  39.50
# |   |   |--- feature_1 <= 41.50
# |   |   |   |--- class: 3
# |   |   |--- feature_1 >  41.50
# |   |   |   |--- class: 1
# |--- feature_3 >  62.00
# |   |--- feature_2 <= 54.00
# |   |   |--- class: 2
# |   |--- feature_2 >  54.00
# |   |   |--- class: 0

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,filled=True)
